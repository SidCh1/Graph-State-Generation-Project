# %%
from calculate_gates_bell_pairs_main import *

# %%
generate_data_BA(num_samples=10,display=True,save_to_file=True)

# %%
generate_data_ER(num_samples=500,display=True,save_to_file=True)

# %%
generate_data_photonic(num_samples=500,circle=True,display=True,save_to_file=True)
